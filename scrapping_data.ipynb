# %%
import pandas as pd
import requests

# %%
url = 'https://www.sofascore.com/api/v1/unique-tournament/8/season/52376/events/round/38'
payload = {}
headers = {
    'authority' : 'www.sofascore.com',
    'accept': '"/"',
    'accept-language': 'en-US;q=0.8,en;q=0.7',
    'cache-control' : 'max-age=0',
    'dnt': '1',
    'if-none-match': 'w/"acce02ee8e"',
    'origin':'https://www.sofascore.com',
    'referer':'https://www.sofascore.com/',
    'sec-ch-ua': '"Not.A/=Brand"; v = "24" ," chromium" ; v="128"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': 'Windows',
    'sec-fetch-dest' : 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'
}

response = requests.request('GET', url=url, headers=headers, data=payload)

# %%
print(response.text)
# Out:
# {"events":[{"tournament":{"name":"LaLiga","slug":"laliga","category":{"name":"Spain","slug":"spain","sport":{"name":"Football","slug":"football","id":1},"id":32,"flag":"spain","alpha2":"ES"},"uniqueTournament":{"name":"LaLiga","slug":"laliga","primaryColorHex":"#2f4a89","secondaryColorHex":"#f4a32e","category":{"name":"Spain","slug":"spain","sport":{"name":"Football","slug":"football","id":1},"id":32,"flag":"spain","alpha2":"ES"},"userCount":1268630,"crowdsourcingEnabled":false,"hasPerformanceGraphFeature":true,"id":8,"hasEventPlayerStatistics":true,"displayInverseHomeAwayTeams":false},"priority":607,"isGroup":false,"isLive":false,"id":36},"season":{"name":"LaLiga 23\/24","year":"23\/24","editor":false,"id":52376},"roundInfo":{"round":38},"customId":"oKjsEAn","status":{"code":100,"description":"Ended","type":"finished"},"winnerCode":1,"homeTeam":{"name":"Girona FC","slug":"girona-fc","shortName":"Girona","gender":"M","sport":{"name":"Football","slug":"football","id":1},"userCount":51
# ...

# %%
matches = response.json()['events']
matches
# Out:
# [{'tournament': {'name': 'LaLiga',
#    'slug': 'laliga',
#    'category': {'name': 'Spain',
#     'slug': 'spain',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 32,
#     'flag': 'spain',
#     'alpha2': 'ES'},
#    'uniqueTournament': {'name': 'LaLiga',
#     'slug': 'laliga',
#     'primaryColorHex': '#2f4a89',
#     'secondaryColorHex': '#f4a32e',
#     'category': {'name': 'Spain',
#      'slug': 'spain',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 32,
#      'flag': 'spain',
#      'alpha2': 'ES'},
#     'userCount': 1268630,
#     'crowdsourcingEnabled': False,
#     'hasPerformanceGraphFeature': True,
#     'id': 8,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 607,
#    'isGroup': False,
#    'isLive': False,
#    'id': 36},
#   'season': {'name': 'LaLiga 23/24',
#    'year': '23/24',
#    'editor': False,
#    'id': 52376},
# ...

# %%
df_matches = pd.DataFrame(matches)
df_matches
# Out:
#                                           tournament  \
# 0  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 1  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 2  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 3  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 4  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 5  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 6  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 7  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 8  {'name': 'LaLiga', 'slug': 'laliga', 'category...
# 9  {'name': 'LaLiga', 'slug': 'laliga', 'category...
#
#                                               season      roundInfo customId  \
# 0  {'name': 'LaLiga 23/24', 'year': '23/24', 'edi...  {'round': 38}  oKjsEAn
# 1  {'name': 'LaLiga 23/24', 'year': '23/24', 'edi...  {'round': 38}  ugbsvgb
# 2  {'name': 'LaLiga 23/24', 'year': '23/24', 'edi...  {'round': 38}  zgbsLgb
# ...

# %%
df_matches.columns
# Out:
# Index(['tournament', 'season', 'roundInfo', 'customId', 'status', 'winnerCode',
#        'homeTeam', 'awayTeam', 'homeScore', 'awayScore', 'time', 'changes',
#        'hasGlobalHighlights', 'hasXg', 'hasEventPlayerStatistics',
#        'hasEventPlayerHeatMap', 'detailId', 'crowdsourcingDataDisplayEnabled',
#        'id', 'awayRedCards', 'crowdsourcingEnabled', 'startTimestamp', 'slug',
#        'finalResultOnly', 'feedLocked', 'isEditor'],
#       dtype='object')

# %%
df_matches['id']
# Out:
# 0    11368614
# 1    11368625
# 2    11368623
# 3    11368639
# 4    11368622
# 5    11368620
# 6    11368618
# 7    11368615
# 8    11368632
# 9    11368617
# Name: id, dtype: int64

# %%
round_games =[]
for game in df_matches['id']:
  round_games.append(game)

print(round_games)
# Out:
# [11368614, 11368625, 11368623, 11368639, 11368622, 11368620, 11368618, 11368615, 11368632, 11368617]

# %%
headers = {
    'authority' : 'www.sofascore.com',
    'accept': '"/"',
    'accept-language': 'en-US;q=0.8,en;q=0.7',
    'cache-control' : 'max-age=0',
    'dnt': '1',
    'if-none-match': 'w/"acce02ee8e"',
    'origin':'https://www.sofascore.com',
    'referer':'https://www.sofascore.com/',
    'sec-ch-ua': '"Not.A/=Brand"; v = "24" ," chromium" ; v="128"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': 'Windows',
    'sec-fetch-dest' : 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'
}

filenames = []
for game in round_games:
  response = requests.get('https://www.sofascore.com/api/v1/event/' + str(game) + '/shotmap', headers=headers)
  filename = 'match_shotmap_' + str(game)
  globals()[f'match_shotmap_{game}'] = response.json()
  filenames.append('match_shotmap_'+str(game))

# %%
filenames
# Out:
# ['match_shotmap_11368614',
#  'match_shotmap_11368625',
#  'match_shotmap_11368623',
#  'match_shotmap_11368639',
#  'match_shotmap_11368622',
#  'match_shotmap_11368620',
#  'match_shotmap_11368618',
#  'match_shotmap_11368615',
#  'match_shotmap_11368632',
#  'match_shotmap_11368617']

# %%
match_shotmap_11368617
# Out:
# {'shotmap': [{'player': {'name': 'Sergio Ramos',
#     'slug': 'sergio-ramos',
#     'shortName': 'S. Ramos',
#     'position': 'D',
#     'userCount': 88097,
#     'id': 10710,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سرجيو, راموس'},
#      'shortNameTranslation': {'ar': 'ر. سرجيو'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 25, 'y': 69.5, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 53.4, 'z': 65.3},
#    'xg': 0.035631462931633,
#    'id': 3294764,
#    'time': 90,
#    'addedTime': 6,
#    'timeSeconds': 5741,
#    'draw': {'start': {'x': 69.5, 'y': 25},
#     'end': {'x': 46.6, 'y': 0},
#     'goal': {'x': 46.6, 'y': 34.7}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 559,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Manu Bueno',
#     'slug': 'bueno-manu',
#     'shortName': 'M. Bueno',
# ...
